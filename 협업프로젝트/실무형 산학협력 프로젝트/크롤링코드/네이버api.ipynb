# %% [markdown]
# # 웹겁색

# %%
import os
import sys
import urllib.request
import pandas as pd
import re # 정규표현식으로 갖고올때 태그 없앨려고 하는거임
import json

client_id = "Z9FeBkITVTDi3gTIV79d"
client_secret = "QXQV83aej9"

search = urllib.parse.quote(input("검색 : "))
idx = 0
display = 100
start = 1
end = 1000

web_df = pd.DataFrame(columns=("Title","Link","Description"))

for start_index in range(start, end, display):

  url = "https://openapi.naver.com/v1/search/webkr?query=" + search \
    + "&display=" + str(display) \
    + "&start=" + str(start_index)

  request = urllib.request.Request(url)
  request.add_header("X-Naver-Client-Id",client_id)
  request.add_header("X-Naver-Client-Secret",client_secret)
  response = urllib.request.urlopen(request)
  rescode = response.getcode()
  if(rescode==200):
      response_body = response.read()
      response_dict = json.loads(response_body.decode('utf-8'))
      items = response_dict['items']
      for item_index in range(0, len(items)):
        remove_tag = re.compile('<.*?>')
        title = re.sub(remove_tag, '',items[item_index]['description'])
        link = items[item_index]['link']
        description = re.sub(remove_tag, '', items[item_index]['description'])
        web_df.loc[idx] = [title, link, description]
        idx += 1
  else:
      print("Error Code:" + rescode)

web_df
# Out:
# 검색 : 컴퓨터
#                                                                                                                                           Title  ...                                                                                                                                 Description
# 0    모두의컴퓨터, 데스크탑 조립PC 전문업체, 표준, 게이밍PC, 모니터, 키보드, 마우스, 스피커, 기타 주변기기 판매                                                                           ...  모두의컴퓨터, 데스크탑 조립PC 전문업체, 표준, 게이밍PC, 모니터, 키보드, 마우스, 스피커, 기타 주변기기 판매
# 1    컴퓨터 및 주변기기, 조립PC 전문 쇼핑몰, 모니터 전산소모품                                                                                                          ...  컴퓨터 및 주변기기, 조립PC 전문 쇼핑몰, 모니터 전산소모품
# 2    디지털/IT, 컴퓨터 본체, pridepc_new4 community portal dcinside                                                                                      ...  디지털/IT, 컴퓨터 본체, pridepc_new4 community portal dcinside
# ...

# %% [markdown]
# # 네이버쇼핑

# %%
import os
import sys
import urllib.request
import pandas as pd
import re # 정규표현식으로 갖고올때 태그 없앨려고 하는거임
import json

pd.set_option('display.max_colwidth', -1) # 데이터프레임 폭 넓히기


client_id = "Z9FeBkITVTDi3gTIV79d"
client_secret = "QXQV83aej9"

search = urllib.parse.quote(input("검색 : "))
idx = 0
display = 100
start = 1
end = 1000
sort = "sim"

shop_df = pd.DataFrame(columns=("Title","Link", "Image", "Low_Price", "High_Price", "Mall_Name", "Product_Id", "Product_Type", "Maker", "Brand"))

for start_index in range(start, end, display):

  url = "https://openapi.naver.com/v1/search/shop?query=" + search \
    + "&display=" + str(display) \
    + "&start=" + str(start_index) \
    + "&start=" + sort

  request = urllib.request.Request(url)
  request.add_header("X-Naver-Client-Id",client_id)
  request.add_header("X-Naver-Client-Secret",client_secret)
  response = urllib.request.urlopen(request)
  rescode = response.getcode()
  if(rescode==200):
      response_body = response.read()
      response_dict = json.loads(response_body.decode('utf-8'))
      items = response_dict['items']
      for item_index in range(0, len(items)):
        remove_tag = re.compile('<.*?>')
        title = re.sub(remove_tag, '',items[item_index]['title'])
        link = items[item_index]['link']
        image = items[item_index]['image']
        low_price = items[item_index]['lprice']
        high_price = items[item_index]['hprice']
        mall_name = items[item_index]['mallName']
        product_id = items[item_index]['productId']
        product_type = items[item_index]['productType']
        maker = items[item_index]['maker']
        brand = items[item_index]['brand']
        
        
        shop_df.loc[idx] = [title, link, image, low_price, high_price, mall_name, product_id, product_type, maker, brand]
        idx += 1
  else:
      print("Error Code:" + rescode)

shop_df
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
# 검색 : 컴퓨터
#                                                   Title  ... Brand
# 0    프리미엄 게이밍 조립컴퓨터 RTX3060 Ti 배틀그라운드 오버워치 배그 본체 사무용 견적  ...  마루PC
# 1    아싸컴 프리미엄 게이밍 i5-9400F + 외장형 그래픽카드                   ...  아싸컴
# 2    게이밍컴퓨터 조립PC 배틀그라운드 서든어택 롤 오버워치 피파온라인4 로스트아크컴퓨터      ...
# 3    LG전자 27V70N-FR50K                                   ...  LG전자
# 4    LG전자 27V70N-GR35K                                   ...  LG전자
# ..                 ...                                   ...   ...
# 995  삼성전자 올인원PC WIN10을 탑재한 부모님 선물로 적합한 인강용 재택근무용 일체형PC   ...  삼성
# 996  애즈락 ASRock DeskMini 310                             ...  애즈락
# 997  로아 피파4 롤 게이밍 조립 컴퓨터 i5-9400F 16G 240G GTX1650       ...
# 998  컴퓨터 중고 본체 조립 i5 3570 3세대 GTX1060 3G                 ...
# ...
