# %% [markdown]
# # Titanic: Machine Learning from Disaster
# ### Predict survival on the Titanic
# - Defining the problem statement
# - Collecting the data
# - Exploratory data analysis
# - Feature engineering
# - Modelling
# - Testing

# %% [markdown]
# ## 1. Defining the problem statement
# Complete the analysis of what sorts of people were likely to survive.
# In particular, we ask you to apply the tools of machine learning to predict which passengers survived the Titanic tragedy.

# %%
from IPython.display import Image
Image(url= "https://static1.squarespace.com/static/5006453fe4b09ef2252ba068/5095eabce4b06cb305058603/5095eabce4b02d37bef4c24c/1352002236895/100_anniversary_titanic_sinking_by_esai8mellows-d4xbme8.jpg")
# Out:
# <img src="https://static1.squarespace.com/static/5006453fe4b09ef2252ba068/5095eabce4b06cb305058603/5095eabce4b02d37bef4c24c/1352002236895/100_anniversary_titanic_sinking_by_esai8mellows-d4xbme8.jpg"/>

# %% [markdown]
# ## 2. Collecting the data
#
# training data set and testing data set are given by Kaggle
# you can download from
# my github [https://github.com/minsuk-heo/kaggle-titanic/tree/master](https://github.com/minsuk-heo/kaggle-titanic)
# or you can download from kaggle directly [kaggle](https://www.kaggle.com/c/titanic/data)
#
# ### load train, test dataset using Pandas

# %%
import pandas as pd

train = pd.read_csv('input/train.csv')
test = pd.read_csv('input/test.csv')

# %% [markdown]
# ## 3. Exploratory data analysis
# Printing first 5 rows of the train dataset.

# %%
train.head(80)

# %% [markdown]
# ### Data Dictionary
# - Survived: 	0 = No, 1 = Yes
# - pclass: 	Ticket class	1 = 1st, 2 = 2nd, 3 = 3rd
# - sibsp:	# of siblings / spouses aboard the Titanic
# - parch:	# of parents / children aboard the Titanic
# - ticket:	Ticket number
# - cabin:	Cabin number
# - embarked:	Port of Embarkation	C = Cherbourg, Q = Queenstown, S = Southampton

# %% [markdown]
# **Total rows and columns**
#
# We can see that there are 891 rows and 12 columns in our training dataset.

# %%
test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
train.shape
# Out:
# (891, 12)

# %%
test.shape
# Out:
# (418, 11)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %% [markdown]
# **다른거 전부 891인데 두개가 714, 204인것으로 보아 여기에 빈 값이 존재한단걸 알 수 있음 -> 추후에 feature engineering으로 채워줘야함**

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
# PassengerId    418 non-null int64
# Pclass         418 non-null int64
# Name           418 non-null object
# Sex            418 non-null object
# Age            332 non-null float64
# SibSp          418 non-null int64
# Parch          418 non-null int64
# Ticket         418 non-null object
# Fare           417 non-null float64
# Cabin          91 non-null object
# Embarked       418 non-null object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.0+ KB

# %% [markdown]
# We can see that *Age* value is missing for many rows.
#
# Out of 891 rows, the *Age* value is present only in 714 rows.
#
# Similarly, *Cabin* values are also missing in many rows. Only 204 out of 891 rows have *Cabin* values.

# %%
train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# **이 방법으로도 빈값 존재여부를 알 수 있음(더 편함)**

# %%
test.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %% [markdown]
# There are 177 rows with missing *Age*, 687 rows with missing *Cabin* and 2 rows with missing *Embarked* information.

# %% [markdown]
# ### import python lib for visualization

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set() # setting seaborn default for plots

# %% [markdown]
# ### Bar Chart for Categorical Features
# - Pclass
# - Sex
# - SibSp ( # of siblings and spouse)
# - Parch ( # of parents and children)
# - Embarked
# - Cabin

# %%
def bar_chart(feature):
    survived = train[train['Survived']==1][feature].value_counts()
    dead = train[train['Survived']==0][feature].value_counts()
    df = pd.DataFrame([survived,dead])
    df.index = ['Survived','Dead']
    df.plot(kind='bar',stacked=True, figsize=(10,5))

# %% [markdown]
# * **입력받은 변수가 죽고 살고에 어떤 영향을 주었는지 그림그려주는 함수!**
# * **survived, dead사이에 비율이 비슷하면 영향이 미미한거고 확실히 차이가 있으면 변수가 타겟에 확실히 영향을 주는것!**

# %%
bar_chart('Sex')

# %% [markdown]
# The Chart confirms **Women** more likely survivied than **Men**

# %%
bar_chart('Pclass')

# %% [markdown]
# The Chart confirms **1st class** more likely survivied than **other classes**
# The Chart confirms **3rd class** more likely dead than **other classes**

# %%
bar_chart('SibSp')

# %% [markdown]
# The Chart confirms **a person aboarded with more than 2 siblings or spouse** more likely survived
# The Chart confirms ** a person aboarded without siblings or spouse** more likely dead

# %%
bar_chart('Parch')

# %% [markdown]
# The Chart confirms **a person aboarded with more than 2 parents or children** more likely survived
# The Chart confirms ** a person aboarded alone** more likely dead

# %%
bar_chart('Embarked')

# %% [markdown]
# The Chart confirms **a person aboarded from C** slightly more likely survived
# The Chart confirms **a person aboarded from Q** more likely dead
# The Chart confirms **a person aboarded from S** more likely dead

# %% [markdown]
# ## 4. Feature engineering
#
# Feature engineering is the process of using domain knowledge of the data
# to create features (**feature vectors**) that make machine learning algorithms work.
#
# feature vector is an n-dimensional vector of numerical features that represent some object.
# Many algorithms in machine learning require a numerical representation of objects,
# since such representations facilitate processing and statistical analysis.

# %% [markdown]
# **feature engineering : 칼럼별로 기존데이터에서 바꿀수있는 것들 전부적용하여 변경!!**

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ### 4.1 how titanic sank?
# sank from the bow of the ship where third class rooms located
# conclusion, Pclass is key feature for classifier

# %%
Image(url= "https://static1.squarespace.com/static/5006453fe4b09ef2252ba068/t/5090b249e4b047ba54dfd258/1351660113175/TItanic-Survival-Infographic.jpg?format=1500w")

# %%
train.head(10)

# %% [markdown]
# ### 4.2 Name

# %%
train_test_data = [train, test] # combining train and test dataset

for dataset in train_test_data:
    dataset['Title'] = dataset['Name'].str.extract(' ([A-Za-z]+)\.', expand=False)

# %%
train['Title'].value_counts()
# Out:
# Mr          517
# Miss        182
# Mrs         125
# Master       40
# Dr            7
# Rev           6
# Col           2
# Major         2
# Mlle          2
# Countess      1
# Ms            1
# Lady          1
# Jonkheer      1
# Don           1
# Mme           1
# Capt          1
# Sir           1
# Name: Title, dtype: int64

# %%
test['Title'].value_counts()
# Out:
# Mr        240
# Miss       78
# Mrs        72
# Master     21
# Col         2
# Rev         2
# Dona        1
# Ms          1
# Dr          1
# Name: Title, dtype: int64

# %% [markdown]
# #### Title map
# Mr : 0
# Miss : 1
# Mrs: 2
# Others: 3

# %%
title_mapping = {"Mr": 0, "Miss": 1, "Mrs": 2, 
                 "Master": 3, "Dr": 3, "Rev": 3, "Col": 3, "Major": 3, "Mlle": 3,"Countess": 3,
                 "Ms": 3, "Lady": 3, "Jonkheer": 3, "Don": 3, "Dona" : 3, "Mme": 3,"Capt": 3,"Sir": 3 }
for dataset in train_test_data:
    dataset['Title'] = dataset['Title'].map(title_mapping)

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Title
# 0      0         A/5 21171   7.2500   NaN        S      0
# 1      0          PC 17599  71.2833   C85        C      2
# 2      0  STON/O2. 3101282   7.9250   NaN        S      1
# 3      0            113803  53.1000  C123        S      2
# ...

# %%
test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked  Title
# 0  34.5      0      0   330911   7.8292   NaN        Q      0
# 1  47.0      1      0   363272   7.0000   NaN        S      2
# 2  62.0      0      0   240276   9.6875   NaN        Q      0
# 3  27.0      0      0   315154   8.6625   NaN        S      0
# 4  22.0      1      1  3101298  12.2875   NaN        S      2

# %%
bar_chart('Title')

# %%
# delete unnecessary feature from dataset
train.drop('Name', axis=1, inplace=True)
test.drop('Name', axis=1, inplace=True)

# %% [markdown]
# **기존 Name 칼럼을 없애고 결혼여부등을 알려줄수있는 Title로 교체**

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# 0            1         0       3    male  22.0      1      0
# 1            2         1       1  female  38.0      1      0
# 2            3         1       3  female  26.0      0      0
# 3            4         1       1  female  35.0      1      0
# 4            5         0       3    male  35.0      0      0
#
#              Ticket     Fare Cabin Embarked  Title
# 0         A/5 21171   7.2500   NaN        S      0
# 1          PC 17599  71.2833   C85        C      2
# 2  STON/O2. 3101282   7.9250   NaN        S      1
# 3            113803  53.1000  C123        S      2
# 4            373450   8.0500   NaN        S      0

# %%
test.head()
# Out:
#    PassengerId  Pclass     Sex   Age  SibSp  Parch   Ticket     Fare Cabin  \
# 0          892       3    male  34.5      0      0   330911   7.8292   NaN
# 1          893       3  female  47.0      1      0   363272   7.0000   NaN
# 2          894       2    male  62.0      0      0   240276   9.6875   NaN
# 3          895       3    male  27.0      0      0   315154   8.6625   NaN
# 4          896       3  female  22.0      1      1  3101298  12.2875   NaN
#
#   Embarked  Title
# 0        Q      0
# 1        S      2
# 2        Q      0
# 3        S      0
# 4        S      2

# %% [markdown]
# ### 4.3 Sex
#
# male: 0
# female: 1

# %%
sex_mapping = {"male": 0, "female": 1}
for dataset in train_test_data:
    dataset['Sex'] = dataset['Sex'].map(sex_mapping)

# %% [markdown]
# **텍스트를 숫자로 변경**

# %%
bar_chart('Sex')

# %% [markdown]
# ### 4.4 Age

# %% [markdown]
# #### 4.4.1 some age is missing
# Let's use Title's median age for missing Age

# %%
train.head(100)

# %%
# fill missing age with median age for each title (Mr, Mrs, Miss, Others)
train["Age"].fillna(train.groupby("Title")["Age"].transform("median"), inplace=True)
test["Age"].fillna(test.groupby("Title")["Age"].transform("median"), inplace=True)

# %% [markdown]
# - **Age 결측치를 채워줘야함**
# - 그냥 전체 평균값으로 결측치 채우는 방법 생각할 수 있음
# - 하지만 남자는 남자의 평균나이로, 여자는 여자의 평균나이로 채우는게 더 과학적
#   - 그래서 결측치를 Title(위에서 새로정의한 칼럼)별 평균나이로 채우는게 더 나아보임
#   - 이때 평균값말고 중앙값을 택하는게 더 좋은경우가 있음. 여기서는 중앙값으로 채택.

# %% [markdown]
# - **중앙값, 평균값에 대한 질문**
#   - 데이터가 유실되었을 때, 중앙값 또는 평균값으로 보통 넣는데요, 저는 중앙값을 넣었어요,**평균값은 데이터가 불균형할 때 사용 안하는 게 좋아요**, 반에 10명의 학생이 있는데 한명이 키가 2미터가 넘을 경우, 평균값에 영향을 주기 때문에 중간 키 값으로 넣어주면 이런 부담이 적어요.

# %%
train.head(30)
train.groupby("Title")["Age"].transform("median")

# %%
facet = sns.FacetGrid(train, hue="Survived",aspect=4)
facet.map(sns.kdeplot,'Age',shade= True)
facet.set(xlim=(0, train['Age'].max()))
facet.add_legend()
 
plt.show()

# %% [markdown]
# **결측치 채웠고, 전체 나이 별 사망여부를 나타낸 그림**

# %%
facet = sns.FacetGrid(train, hue="Survived",aspect=4)
facet.map(sns.kdeplot,'Age',shade= True)
facet.set(xlim=(0, train['Age'].max()))
facet.add_legend()
plt.xlim(0, 20)
# Out:
# (0, 20)

# %% [markdown]
# **지금부턴 연령별로 좀 더 세부적인 그림**

# %%
facet = sns.FacetGrid(train, hue="Survived",aspect=4)
facet.map(sns.kdeplot,'Age',shade= True)
facet.set(xlim=(0, train['Age'].max()))
facet.add_legend()
plt.xlim(20, 30)
# Out:
# (20, 30)

# %%
facet = sns.FacetGrid(train, hue="Survived",aspect=4)
facet.map(sns.kdeplot,'Age',shade= True)
facet.set(xlim=(0, train['Age'].max()))
facet.add_legend()
plt.xlim(30, 40)
# Out:
# (30, 40)

# %%
facet = sns.FacetGrid(train, hue="Survived",aspect=4)
facet.map(sns.kdeplot,'Age',shade= True)
facet.set(xlim=(0, train['Age'].max()))
facet.add_legend()
plt.xlim(40, 60)
# Out:
# (40, 60)

# %%
facet = sns.FacetGrid(train, hue="Survived",aspect=4)
facet.map(sns.kdeplot,'Age',shade= True)
facet.set(xlim=(0, train['Age'].max()))
facet.add_legend()
plt.xlim(40, 60)
# Out:
# (40, 60)

# %%
facet = sns.FacetGrid(train, hue="Survived",aspect=4)
facet.map(sns.kdeplot,'Age',shade= True)
facet.set(xlim=(0, train['Age'].max()))
facet.add_legend()
plt.xlim(60)
# Out:
# (60, 80.0)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Sex            891 non-null int64
# Age            891 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# Title          891 non-null int64
# dtypes: float64(2), int64(7), object(3)
# memory usage: 83.6+ KB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
# PassengerId    418 non-null int64
# Pclass         418 non-null int64
# Sex            418 non-null int64
# Age            418 non-null float64
# SibSp          418 non-null int64
# Parch          418 non-null int64
# Ticket         418 non-null object
# Fare           417 non-null float64
# Cabin          91 non-null object
# Embarked       418 non-null object
# Title          418 non-null int64
# dtypes: float64(2), int64(6), object(3)
# memory usage: 36.0+ KB

# %% [markdown]
# #### 4.4.2 Binning
# * **Bining : sequential한 정보가 있을때 그게 하나하나가 타겟에 유의미하지않은경우 카테고리화 시키는 방법.**
#
# Binning/Converting Numerical Age to Categorical Variable
#
# feature vector map:
# child: 0
# young: 1
# adult: 2
# mid-age: 3
# senior: 4

# %% [markdown]
# * **Binnig 나이설정 관련 질문**
#
# **비닝은 각 도메인애 따라 달라질 수 있어요. 타이타닉 같은 경우 아이와 노인은 살 확률이 높았다는 가정하에 비닝을 한것처럼, 다른 문제인 경우, 비닝은 달라질 수 있어요. 이런 피쳐 엠지니어링의 어려움 때문에 딥러닝이 급부상 된것도 있어요. 딥러닝은 우리가 따로 설정을 안해줘도 스스로 weight를 조정해서 그 답을 찾습니다.**

# %% [markdown]
# **원 핫 인코딩의 경우 특징들간에 유사도가 아예 없어집니다. Integer encoding의 경우 가까운 숫자에 더 유사도가 생기게 됩니다**

# %%
for dataset in train_test_data:
    dataset.loc[ dataset['Age'] <= 16, 'Age'] = 0,
    dataset.loc[(dataset['Age'] > 16) & (dataset['Age'] <= 26), 'Age'] = 1,
    dataset.loc[(dataset['Age'] > 26) & (dataset['Age'] <= 36), 'Age'] = 2,
    dataset.loc[(dataset['Age'] > 36) & (dataset['Age'] <= 62), 'Age'] = 3,
    dataset.loc[ dataset['Age'] > 62, 'Age'] = 4

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  Sex  Age  SibSp  Parch            Ticket  \
# 0            1         0       3    0  1.0      1      0         A/5 21171
# 1            2         1       1    1  3.0      1      0          PC 17599
# 2            3         1       3    1  1.0      0      0  STON/O2. 3101282
# 3            4         1       1    1  2.0      1      0            113803
# 4            5         0       3    0  2.0      0      0            373450
#
#       Fare Cabin Embarked  Title
# 0   7.2500   NaN        S      0
# 1  71.2833   C85        C      2
# 2   7.9250   NaN        S      1
# 3  53.1000  C123        S      2
# 4   8.0500   NaN        S      0

# %%
bar_chart('Age')

# %% [markdown]
# ### 4.5 Embarked(탑승 선착장 종류)

# %% [markdown]
# #### 4.5.1 filling missing values

# %%
Pclass1 = train[train['Pclass']==1]['Embarked'].value_counts()
Pclass2 = train[train['Pclass']==2]['Embarked'].value_counts()
Pclass3 = train[train['Pclass']==3]['Embarked'].value_counts()
df = pd.DataFrame([Pclass1, Pclass2, Pclass3])
df.index = ['1st class','2nd class', '3rd class']
df.plot(kind='bar',stacked=True, figsize=(10,5))

# %% [markdown]
# **좌석 클래스별 embarked(선착장) 구성비율**

# %% [markdown]
# more than 50% of 1st class are from S embark
# more than 50% of 2nd class are from S embark
# more than 50% of 3rd class are from S embark
#
# **fill out missing embark with S embark**

# %%
for dataset in train_test_data:
    dataset['Embarked'] = dataset['Embarked'].fillna('S')

# %% [markdown]
# **embarked에 대한 결측치를 가장 많은빈도인 S로 그냥 다 채우기로함**

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  Sex  Age  SibSp  Parch            Ticket  \
# 0            1         0       3    0  1.0      1      0         A/5 21171
# 1            2         1       1    1  3.0      1      0          PC 17599
# 2            3         1       3    1  1.0      0      0  STON/O2. 3101282
# 3            4         1       1    1  2.0      1      0            113803
# 4            5         0       3    0  2.0      0      0            373450
#
#       Fare Cabin Embarked  Title
# 0   7.2500   NaN        S      0
# 1  71.2833   C85        C      2
# 2   7.9250   NaN        S      1
# 3  53.1000  C123        S      2
# 4   8.0500   NaN        S      0

# %%
embarked_mapping = {"S": 0, "C": 1, "Q": 2} 
for dataset in train_test_data:
    dataset['Embarked'] = dataset['Embarked'].map(embarked_mapping)

# %% [markdown]
# **마지막엔 텍스트들을 숫자로 맵핑. (근데 이거 수치관계 이것도 없애야할텐데.. 그게 인코딩아닌가)**

# %% [markdown]
# ### 4.6 Fare(요금)

# %%
# fill missing Fare with median fare for each Pclass
train["Fare"].fillna(train.groupby("Pclass")["Fare"].transform("median"), inplace=True)
test["Fare"].fillna(test.groupby("Pclass")["Fare"].transform("median"), inplace=True)
train.head(50)

# %% [markdown]
# **요금은 사실 결측치가 없긴한데 만약에 있었을경우, 가장 요금과 연관관계가 있는 좌석요금에 따라서 그거의 중앙값으로 결측치를 채운다**

# %%
facet = sns.FacetGrid(train, hue="Survived",aspect=4)
facet.map(sns.kdeplot,'Fare',shade= True)
facet.set(xlim=(0, train['Fare'].max()))
facet.add_legend()
 
plt.show()

# %%
facet = sns.FacetGrid(train, hue="Survived",aspect=4)
facet.map(sns.kdeplot,'Fare',shade= True)
facet.set(xlim=(0, train['Fare'].max()))
facet.add_legend()
plt.xlim(0, 20)
# Out:
# (0, 20)

# %%
facet = sns.FacetGrid(train, hue="Survived",aspect=4)
facet.map(sns.kdeplot,'Fare',shade= True)
facet.set(xlim=(0, train['Fare'].max()))
facet.add_legend()
plt.xlim(0, 30)
# Out:
# (0, 30)

# %%
facet = sns.FacetGrid(train, hue="Survived",aspect=4)
facet.map(sns.kdeplot,'Fare',shade= True)
facet.set(xlim=(0, train['Fare'].max()))
facet.add_legend()
plt.xlim(0)
# Out:
# (0, 512.32920000000001)

# %%
for dataset in train_test_data:
    dataset.loc[ dataset['Fare'] <= 17, 'Fare'] = 0,
    dataset.loc[(dataset['Fare'] > 17) & (dataset['Fare'] <= 30), 'Fare'] = 1,
    dataset.loc[(dataset['Fare'] > 30) & (dataset['Fare'] <= 100), 'Fare'] = 2,
    dataset.loc[ dataset['Fare'] > 100, 'Fare'] = 3

# %% [markdown]
# **그리고 마찬가지로 카테고리화 시켜준다**

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  Sex  Age  SibSp  Parch            Ticket  \
# 0            1         0       3    0  1.0      1      0         A/5 21171
# 1            2         1       1    1  3.0      1      0          PC 17599
# 2            3         1       3    1  1.0      0      0  STON/O2. 3101282
# 3            4         1       1    1  2.0      1      0            113803
# 4            5         0       3    0  2.0      0      0            373450
#
#    Fare Cabin  Embarked  Title
# 0   0.0   NaN         0      0
# 1   2.0   C85         1      2
# 2   0.0   NaN         0      1
# 3   2.0  C123         0      2
# 4   0.0   NaN         0      0

# %% [markdown]
# ### 4.7 Cabin (객실등급)

# %%
train.Cabin.value_counts()
# Out:
# C23 C25 C27        4
# G6                 4
# B96 B98            4
# D                  3
# C22 C26            3
# E101               3
# F2                 3
# F33                3
# B57 B59 B63 B66    2
# C68                2
# B58 B60            2
# E121               2
# D20                2
# E8                 2
# E44                2
# B77                2
# C65                2
# D26                2
# E24                2
# E25                2
# B20                2
# C93                2
# D33                2
# E67                2
# D35                2
# D36                2
# C52                2
# F4                 2
# C125               2
# C124               2
#                   ..
# F G63              1
# A6                 1
# D45                1
# D6                 1
# D56                1
# C101               1
# C54                1
# D28                1
# D37                1
# B102               1
# D30                1
# E17                1
# ...

# %%
for dataset in train_test_data:
    dataset['Cabin'] = dataset['Cabin'].str[:1]

# %%
Pclass1 = train[train['Pclass']==1]['Cabin'].value_counts()
Pclass2 = train[train['Pclass']==2]['Cabin'].value_counts()
Pclass3 = train[train['Pclass']==3]['Cabin'].value_counts()
df = pd.DataFrame([Pclass1, Pclass2, Pclass3])
df.index = ['1st class','2nd class', '3rd class']
df.plot(kind='bar',stacked=True, figsize=(10,5))

# %% [markdown]
# - **pclass별 cabin 구성확인**
# - **1등급에만 있는 pclass가 있음을 확인**

# %%
cabin_mapping = {"A": 0, "B": 0.4, "C": 0.8, "D": 1.2, "E": 1.6, "F": 2, "G": 2.4, "T": 2.8}
for dataset in train_test_data:
    dataset['Cabin'] = dataset['Cabin'].map(cabin_mapping)

# %% [markdown]
# **mapping 0부터 매겨주는건데 저렇게 소수점 되어있는거는, 0부터 시작해서 그냥 같은비율만큼 거리준건데 다른 칼럼의 값의 범위랑 맞추려다보니 저렇게된거다**

# %% [markdown]
# Q. cabin 같은 경우에 영상처럼 feature engineering을 할 경우 **A,B,C,D 사이에는 연관성이 없지만 0, 0,4, 0.8 등등의 값은 서로의 차이에 따라 연관성이** 생긴다는 문제점이 있지 않나요??

# %% [markdown]
# 좋은 질문 감사합니다. 말씀해주신대로, feature engineering 할 때, 연관성이 있는 특징의 연관성을 살려주고, 반면에 연관성이 떨어질 경우, 연관성을 줄여줘야합니다. 제가 개인적으로 분석했을 때는 **A,B,C 캐빈은 오로지 1 class에서만 사용되었고,  D,E,F는 2 class 그 이후의 캐빈은 3 class에서 사용되었고 그 연관성을 숫자의 크기에 넣었다고 보셔도 될 것 같습니다.** 즉, {"A": 0, "B": 0.4, "C": 0.8, "D": 1.2, "E": 1.6, "F": 2, "G": 2.4, "T": 2.8}로 매핑할 경우,**낮은 숫자는 1등급 사람들, 즉 살아난 확률이 많은 클래스의 연관성이 커지고, 높은 숫자는 3등급, 즉 비생존 확률이** 높아질 것으로 보입니다.

# %%
# fill missing Fare with median fare for each Pclass
train["Cabin"].fillna(train.groupby("Pclass")["Cabin"].transform("median"), inplace=True)
test["Cabin"].fillna(test.groupby("Pclass")["Cabin"].transform("median"), inplace=True)

# %% [markdown]
# **pcalss에 따라 결측치 채워준다**

# %% [markdown]
# ### 4.8 FamilySize

# %%
train["FamilySize"] = train["SibSp"] + train["Parch"] + 1
test["FamilySize"] = test["SibSp"] + test["Parch"] + 1

# %% [markdown]
# **자녀여부, 동승부모 여부등을 나타내는 변수들의 값을 서로합쳐서 FamilySize라는 새 칼럼을 만듦. +1한 이유는 0,0인경우에 본인도 있으니까..**

# %%
facet = sns.FacetGrid(train, hue="Survived",aspect=4)
facet.map(sns.kdeplot,'FamilySize',shade= True)
facet.set(xlim=(0, train['FamilySize'].max()))
facet.add_legend()
plt.xlim(0)
# Out:
# (0, 11.0)

# %% [markdown]
# **이렇게 그림으로 봤을때 이 변수 값에 따라 타겟변수에 영향이 있음을 알수있으므로 이렇게 피쳐엔지니어링 해준것이 유효한 작업이란거지**

# %%
family_mapping = {1: 0, 2: 0.4, 3: 0.8, 4: 1.2, 5: 1.6, 6: 2, 7: 2.4, 8: 2.8, 9: 3.2, 10: 3.6, 11: 4}
for dataset in train_test_data:
    dataset['FamilySize'] = dataset['FamilySize'].map(family_mapping)

# %% [markdown]
# **마찬가지로 카테고리화 해주고..**

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  Sex  Age  SibSp  Parch            Ticket  \
# 0            1         0       3    0  1.0      1      0         A/5 21171
# 1            2         1       1    1  3.0      1      0          PC 17599
# 2            3         1       3    1  1.0      0      0  STON/O2. 3101282
# 3            4         1       1    1  2.0      1      0            113803
# 4            5         0       3    0  2.0      0      0            373450
#
#    Fare  Cabin  Embarked  Title  FamilySize
# 0   0.0    2.0         0      0         0.4
# 1   2.0    0.8         1      2         0.4
# 2   0.0    2.0         0      1         0.0
# 3   2.0    0.8         0      2         0.4
# 4   0.0    2.0         0      0         0.0

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  Sex  Age  SibSp  Parch            Ticket  \
# 0            1         0       3    0  1.0      1      0         A/5 21171
# 1            2         1       1    1  3.0      1      0          PC 17599
# 2            3         1       3    1  1.0      0      0  STON/O2. 3101282
# 3            4         1       1    1  2.0      1      0            113803
# 4            5         0       3    0  2.0      0      0            373450
#
#    Fare  Cabin  Embarked  Title  FamilySize
# 0   0.0    2.0         0      0         0.4
# 1   2.0    0.8         1      2         0.4
# 2   0.0    2.0         0      1         0.0
# 3   2.0    0.8         0      2         0.4
# 4   0.0    2.0         0      0         0.0

# %%
features_drop = ['Ticket', 'SibSp', 'Parch']
train = train.drop(features_drop, axis=1)
test = test.drop(features_drop, axis=1)
train = train.drop(['PassengerId'], axis=1)

# %% [markdown]
# **FaimlySize에 들어간 SibSP,Parch랑.. 그리고 필요없는정보로 판단되는 Ticket칼럼을 아예 drop조치해줌**

# %%
train_data = train.drop('Survived', axis=1)
target = train['Survived']

train_data.shape, target.shape
# Out:
# ((891, 8), (891,))

# %%
train_data.head(10)
# Out:
#    Pclass  Sex  Age  Fare  Cabin  Embarked  Title  FamilySize
# 0       3    0  1.0   0.0    2.0         0      0         0.4
# 1       1    1  3.0   2.0    0.8         1      2         0.4
# 2       3    1  1.0   0.0    2.0         0      1         0.0
# 3       1    1  2.0   2.0    0.8         0      2         0.4
# 4       3    0  2.0   0.0    2.0         0      0         0.0
# 5       3    0  2.0   0.0    2.0         2      0         0.0
# 6       1    0  3.0   2.0    1.6         0      0         0.0
# 7       3    0  0.0   1.0    2.0         0      3         1.6
# 8       3    1  2.0   0.0    2.0         0      2         0.8
# 9       2    1  0.0   2.0    1.8         1      2         0.4

# %% [markdown]
# **최종 전처리 완료된 df**

# %% [markdown]
# ## 5. Modelling

# %% [markdown]
# ### 각 분류기별 원리

# %% [markdown]
# **1. KNN**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# (지금은 변수8개지만, 2개라고 가정하고) 분류할 데이터 가장 이웃한 데이터를 보고 다수결로 결정.

# %% [markdown]
# **2. DECISION TREE**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **3. RANDOM FOREST**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **4. NAIVE BAYES** (확률로 접근하는 방법)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **5. SVM**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 저 선 기준으로 영역에따라 분류가되는 원리.

# %% [markdown]
# ### 모델링준비

# %%
# Importing Classifier Modules
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC

import numpy as np

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
# Survived      891 non-null int64
# Pclass        891 non-null int64
# Sex           891 non-null int64
# Age           891 non-null float64
# Fare          891 non-null float64
# Cabin         891 non-null float64
# Embarked      891 non-null int64
# Title         891 non-null int64
# FamilySize    891 non-null float64
# dtypes: float64(4), int64(5)
# memory usage: 62.7 KB

# %% [markdown]
# ### 6.2 Cross Validation (K-fold)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **어느것을 택하느냐에 따라 정확도가 당연히 달라질 수 있음**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **그래서 각 영역별(fold별) 정확도의 평균으로 채택**

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
k_fold = KFold(n_splits=10, shuffle=True, random_state=0) # 이걸 cross_Val_score의 인자로 활용하게됨

# %% [markdown]
# ### 6.2.1 kNN

# %%
clf = KNeighborsClassifier(n_neighbors = 13)
scoring = 'accuracy'
score = cross_val_score(clf, train_data, target, cv=k_fold, n_jobs=1, scoring=scoring)
print(score)
# Out:
# [ 0.82222222  0.76404494  0.80898876  0.83146067  0.87640449  0.82022472
#   0.85393258  0.79775281  0.84269663  0.84269663]

# %%
# kNN Score
round(np.mean(score)*100, 2)
# Out:
# 82.6

# %% [markdown]
# ### 6.2.2 Decision Tree

# %%
clf = DecisionTreeClassifier()
scoring = 'accuracy'
score = cross_val_score(clf, train_data, target, cv=k_fold, n_jobs=1, scoring=scoring)
print(score)
# Out:
# [ 0.76666667  0.82022472  0.78651685  0.76404494  0.88764045  0.76404494
#   0.82022472  0.82022472  0.74157303  0.79775281]

# %%
# decision tree Score
round(np.mean(score)*100, 2)
# Out:
# 79.69

# %% [markdown]
# ### 6.2.3 Ramdom Forest

# %%
clf = RandomForestClassifier(n_estimators=13)
scoring = 'accuracy'
score = cross_val_score(clf, train_data, target, cv=k_fold, n_jobs=1, scoring=scoring)
print(score)
# Out:
# [ 0.77777778  0.80898876  0.82022472  0.76404494  0.86516854  0.82022472
#   0.79775281  0.80898876  0.76404494  0.83146067]

# %%
# Random Forest Score
round(np.mean(score)*100, 2)
# Out:
# 80.59

# %% [markdown]
# ### 6.2.4 Naive Bayes

# %%
clf = GaussianNB()
scoring = 'accuracy'
score = cross_val_score(clf, train_data, target, cv=k_fold, n_jobs=1, scoring=scoring)
print(score)
# Out:
# [ 0.85555556  0.73033708  0.75280899  0.75280899  0.70786517  0.80898876
#   0.76404494  0.80898876  0.86516854  0.83146067]

# %%
# Naive Bayes Score
round(np.mean(score)*100, 2)
# Out:
# 78.78

# %% [markdown]
# ### 6.2.5 SVM

# %%
clf = SVC()
scoring = 'accuracy'
score = cross_val_score(clf, train_data, target, cv=k_fold, n_jobs=1, scoring=scoring)
print(score)
# Out:
# [ 0.83333333  0.80898876  0.83146067  0.82022472  0.84269663  0.82022472
#   0.84269663  0.85393258  0.83146067  0.86516854]

# %%
round(np.mean(score)*100,2)
# Out:
# 83.5

# %% [markdown]
# ## 7. Testing

# %%
clf = SVC()
clf.fit(train_data, target)

test_data = test.drop("PassengerId", axis=1).copy()
prediction = clf.predict(test_data)

# %%
submission = pd.DataFrame({
        "PassengerId": test["PassengerId"],
        "Survived": prediction
    })

submission.to_csv('submission.csv', index=False)

# %%
submission = pd.read_csv('submission.csv')
submission.head()
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         1
# 2          894         0
# 3          895         0
# 4          896         1

# %% [markdown]
# ## References
#
# This notebook is created by learning from the following notebooks:
#
# - [Mukesh ChapagainTitanic Solution: A Beginner's Guide](https://www.kaggle.com/chapagain/titanic-solution-a-beginner-s-guide?scriptVersionId=1473689)
# - [How to score 0.8134 in Titanic Kaggle Challenge](http://ahmedbesbes.com/how-to-score-08134-in-titanic-kaggle-challenge.html)
# - [Titanic: factors to survive](https://olegleyz.github.io/titanic_factors.html)
# - [Titanic Survivors Dataset and Data Wrangling](http://www.codeastar.com/data-wrangling/)
