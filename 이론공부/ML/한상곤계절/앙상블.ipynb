# %%
from sklearn.datasets import load_iris, load_wine, load_boston, load_diabetes
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import cross_validate, cross_val_score

# %%
iris = load_iris()
wine = load_wine()
boston = load_boston()
diabetes = load_diabetes()

# %% [markdown]
# ## 투표 기반 분류와 회귀

# %%
from sklearn.ensemble import VotingClassifier, VotingRegressor

# %% [markdown]
# ### 투표 기반 분류

# %%
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import SGDClassifier

# %%
model1 = SVC()
model2 = GaussianNB()
model3 = SGDClassifier()

# %%
vote_model = VotingClassifier(
    estimators=[('svc', model1), ('gaussian', model2), ('sgd', model3)]
)

# %%
for model in (model1, model2, model3, vote_model):
  model_name = str(type(model)).split('.')[-1][:-2]
  scores = cross_val_score(model, iris.data, iris.target, cv=5)
  print(f'{model_name}, Accuracy : {scores.mean()}')
# Out:
# SVC, Accuracy : 0.9666666666666666
# GaussianNB, Accuracy : 0.9533333333333334
# SGDClassifier, Accuracy : 0.7533333333333333
# VotingClassifier, Accuracy : 0.9666666666666668

# %% [markdown]
# ### 투표 기반 회귀

# %%
from sklearn.svm import SVR
from sklearn.linear_model import SGDRegressor, LinearRegression

# %%
model1 = SVR()
model2 = SGDRegressor()
model3 = LinearRegression()

# %%
vote_model = VotingRegressor(
    estimators = [('svr', model1), ('sgd', model2), ('linear', model3)]
)

# %%
for model in (model1, model2, model3, vote_model):
  model_name = str(type(model)).split('.')[-1][:-2]
  scores = -cross_val_score(model, boston.data, boston.target, scoring = 'neg_mean_squared_error', cv=5)
  print(f'{model_name}, Accuracy : {scores.mean()}')
# Out:
# SVR, Accuracy : 71.85800739156483
# SGDRegressor, Accuracy : 2.289295103969523e+28
# LinearRegression, Accuracy : 37.13180746769903
# VotingRegressor, Accuracy : 2.92057463812002e+27

# %% [markdown]
# * 투표기반 회귀는 잘 안쓴다고 함!!
# * 글구 회귀만 앞에 -랑, 끝에 neg_mean은 뭐 회귀라서 쓰이는 그리고 사이킷런 특징이란다 그냥 그런갑다 하기

# %% [markdown]
# ## 배깅

# %% [markdown]
# ## AdaBoost
