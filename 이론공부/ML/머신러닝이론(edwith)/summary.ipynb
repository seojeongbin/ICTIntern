# %% [markdown]
# - 각 챕터에서의 (기술적인 측면의) 꿀팁을 정리함.
# - 이론적인 부분이나 그 챕터에서만 활용가능한 부분들은 그 챕터를 찾아가서 다시 볼 것

# %% [markdown]
# ## 회귀 평가지표
# - 참고 : 선형회귀

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 2. 분류 평가지료
# - 참고 : 선형분류

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 3. 교차검증
# - 참고 : 앙상블

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - train, test split은 그냥 검증세트를 만드는것뿐임
#   - 검증세트 만드는 이유 : 과소적합인지, 과대적합인지 체크하기위함
# - cross_val_score : 이건 검증중에서도 교차검증
#   - 회귀 : kfold
#   - 분류 : stratifiedKFlod
#     - 이렇게 두가지정도로만 나뉘는거 알고있음 됨. 실제 쓸 때 구글링 ㄱㄱ
# - "GridSearchCV" : 그리드탐색 + 교차검증 한번에 가능
#   - 핸즈온머신러닝책에 잘 써있으니 참고하기.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 4. mkae_pipeline

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 5. 비지도학습
# - 지도학습의 목표가 예측이라면, 비지도는 데이터의 차원축소나 유사한것끼리의 군집화가 목표
# - 1. 군집화
#   - 라벨이 없는 상태에서 분석하여 유사정도 따라 분류
#   - 각 샘플별 유사도를 계산하여 유사끼리 군집화
# - 2. PCA
#   - 차원축소
#     - 독립변수간 상관관계 있으면 결과 부정적일 수 있으므로 제거 / 컴퓨팅 자원 이슈
#   - (캐리커쳐 같은느낌) 정확도는 감소하지만 속도는 빨라짐
#     - * LDA : 레이블정보를 활용한 차원축소 (즉 비지도학습은 아니고 지도학습에 속할듯?)
