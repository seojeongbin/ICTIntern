# %% [markdown]
# ## OpenCV Filtering

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-a4b89db6-b650-48ad-84f1-e025f3518343" name="files[]" multiple disabled />
#      <output id="result-a4b89db6-b650-48ad-84f1-e025f3518343">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving gray_image.jpg to gray_image.jpg

# %% [markdown]
# - 이미지에 커널을 적용하여 이미지를 흐리게(Blurring = Smoothing) 처리할 수 있습니다.
# - 이미지를 흐리게 만들면 노이즈 및 손상을 줄일 수 있습니다.
# - 특정한 이미지에서 커널(Kernel)을 적용해 컨볼루션 계산하여 필터링을 수행할 수 있습니다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - 2에 해당하는 이미지에 필터(블러링 등)을 적용하고 싶을때, "커널"을 이용해서 바뀐값 4로 변경조치 해주는 것임!

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - 대표적 커널 종류 두가지
#   - 베이직 커널 : 가중치 전부 똑같이 한 후 평균
#   - 가우시안 커널 : 정규분포모양 처럼 가운데 부분(필터링 적용하고자 하는것에 가까울수록 가중치) 해당하는것에 좀 더 가중치 준 후 평균

# %% [markdown]
# ### 직접 커널을 생성하여 필터 적용하기

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

image = cv2.imread('gray_image.jpg')
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.show()

size = 4
kernel = np.ones((size, size), np.float32) / (size ** 2)
print(kernel)

dst = cv2.filter2D(image, -1, kernel)
plt.imshow(cv2.cvtColor(dst, cv2.COLOR_BGR2RGB))
plt.show()
# Out:
# [[0.0625 0.0625 0.0625 0.0625]
#  [0.0625 0.0625 0.0625 0.0625]
#  [0.0625 0.0625 0.0625 0.0625]
#  [0.0625 0.0625 0.0625 0.0625]]

# %% [markdown]
# ### Basic Blurring

# %%
import cv2
import matplotlib.pyplot as plt

image = cv2.imread('gray_image.jpg')
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.show()

dst = cv2.blur(image, (4, 4)) # 이게 위에서 한거랑 똑같은 결과임
plt.imshow(cv2.cvtColor(dst, cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# ### Gaussian Blur

# %%
import cv2

image = cv2.imread('gray_image.jpg')
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.show()

# 이때 kernel_size: 홀수 여야만 함!
dst = cv2.GaussianBlur(image, (5, 5), 0)
plt.imshow(cv2.cvtColor(dst, cv2.COLOR_BGR2RGB))
plt.show()
