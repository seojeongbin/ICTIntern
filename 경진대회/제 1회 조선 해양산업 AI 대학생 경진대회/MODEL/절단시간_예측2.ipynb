# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from sklearn.metrics import mean_absolute_error, mean_squared_error, explained_variance_score
from sklearn.ensemble import RandomForestRegressor, ExtraTreesRegressor

# %%
Data = pd.read_csv("cutting.csv")
Data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-14660bbc29f4> in <module>()
# ----> 1 Data = pd.read_csv("cutting.csv")
#       2 Data
#
# NameError: name 'pd' is not defined

# %%
Data.info
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-20392441b658> in <module>()
# ----> 1 Data.info
#
# NameError: name 'Data' is not defined

# %%
Data.columns
# Out:
# Index(['Unnamed: 0', '절단 길이 (m)', '절단갯수', '절단시간(초)', '철판재질_32M60C  ',
#        '철판재질_9NI     ', '철판재질_A       ', '철판재질_AA      ', '철판재질_AAH32   ',
#        '철판재질_AAH32-TM',
#        ...
#        '절단장비_PL273', '절단장비_PL911', '절단장비_PL921', '절단장비_PL922', '절단장비_PL961',
#        '절단장비_PL973', '절단장비_PL974', '절단장비_PS213', '절단장비_PS243', '절단장비_PS963'],
#       dtype='object', length=122)

# %%
del Data['Unnamed: 0']

# %%
from sklearn.model_selection import train_test_split

y = Data['절단시간(초)']
x = Data.drop(['절단시간(초)'],axis=1, inplace=False)

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.4, random_state=0)

# %%
# 그냥 랜덤포레스트 일반 0.4) 98129 / 84855
model = RandomForestRegressor()
model.fit(x_train, y_train)

train_score= model.score(x_train, y_train)
print(train_score)

pred =model.predict(x_test)

test_score= explained_variance_score(pred, y_test)
print(test_score)
gap = train_score - test_score
print("학습률 예측률 차이 :", gap)
RMSE = mean_squared_error(y_test, pred)**0.5
print("rmse: ", RMSE)
# Out:
# 'test_score= explained_variance_score(pred, y_test)\nprint(test_score)\ngap = train_score - test_score\nprint("학습률 예측률 차이 :", gap)\nRMSE = mean_squared_error(y_test, pred)**0.5\nprint("rmse: ", RMSE)'

# %%
pred = model.predict(x)
Data['절단 예측시간 '] = pred
Data
# Out:
#         절단 길이 (m)  절단갯수  절단시간(초)  ...  절단장비_PS243  절단장비_PS963     절단 예측시간
# 0            21.9     1      827  ...           0           0   681.641000
# 1           111.8    46     2906  ...           0           0  2878.176667
# 2            33.5     2     1003  ...           0           0   922.475667
# 3           174.9    35     4412  ...           0           0  4693.553333
# 4            66.6     7     1601  ...           0           0  1627.965762
# ...           ...   ...      ...  ...         ...         ...          ...
# 144402      124.0    33     3077  ...           0           0  3752.583000
# 144403      162.0    31     2899  ...           0           0  4370.956667
# 144404       28.9    56      930  ...           0           0  1038.670000
# 144405       25.6     1      696  ...           0           0   780.475000
# 144406       20.7     8      678  ...           0           0   867.440000
#
# [144407 rows x 122 columns]

# %%
Data.to_csv('절단시간절단시간.csv',encoding='utf-8')

# %%
model = RandomForestRegressor(n_estimators=200) 
model.fit(x_train, y_train)

train_score= model.score(x_train, y_train)
print(train_score)

pred =model.predict(x_test)

test_score= explained_variance_score(pred, y_test)
print(test_score)
gap = train_score - test_score
print("학습률 예측률 차이 :", gap)
RMSE = mean_squared_error(y_test, pred)**0.5
print("rmse: ", RMSE)
# Out:
# 0.9697863600711872
# 0.8318088310219077
# 학습률 예측률 차이 : 0.1379775290492795
# rmse:  429.93201415703595

# %%
model = RandomForestRegressor(min_samples_split=2, min_samples_leaf = 1, n_estimators=300, max_depth=300) 
model.fit(x_train, y_train)

train_score= model.score(x_train, y_train)
print(train_score)

pred =model.predict(x_test)

test_score= explained_variance_score(pred, y_test)
print(test_score)
gap = train_score - test_score
print("학습률 예측률 차이 :", gap)
RMSE = mean_squared_error(y_test, pred)**0.5
print("rmse: ", RMSE)
# Out:
# 0.9699176724709193
# 0.832341395297958
# 학습률 예측률 차이 : 0.13757627717296128
# rmse:  429.44486362947674

# %%
model = RandomForestRegressor(min_samples_split=2, min_samples_leaf = 1, n_estimators=1000, max_depth=1000) 
model.fit(x_train, y_train)

train_score= model.score(x_train, y_train)
print(train_score)

pred =model.predict(x_test)

test_score= explained_variance_score(pred, y_test)
print(test_score)
gap = train_score - test_score
print("학습률 예측률 차이 :", gap)
RMSE = mean_squared_error(y_test, pred)**0.5
print("rmse: ", RMSE)
# Out:
# 0.9700627147771765
# 0.8325736149125262
# 학습률 예측률 차이 : 0.1374890998646503
# rmse:  428.8753954088334

# %%
pred22 = model.predict(x)
Data['예측 절단시간'] = pred22
Data
# Out:
#         절단 길이 (m)  절단갯수  절단시간(초)  ...  절단장비_PS243  절단장비_PS963      예측 절단시간
# 0            21.9     1      827  ...           0           0   660.589741
# 1           111.8    46     2906  ...           0           0  2926.959750
# 2            33.5     2     1003  ...           0           0   923.501573
# 3           174.9    35     4412  ...           0           0  4641.921787
# 4            66.6     7     1601  ...           0           0  1647.320237
# ...           ...   ...      ...  ...         ...         ...          ...
# 144402      124.0    33     3077  ...           0           0  3752.382226
# 144403      162.0    31     2899  ...           0           0  4377.482664
# 144404       28.9    56      930  ...           0           0  1030.357600
# 144405       25.6     1      696  ...           0           0   792.324400
# 144406       20.7     8      678  ...           0           0   770.274758
#
# [144407 rows x 122 columns]

# %%
data22 = Data.iloc[:,-1]
data22
# Out:
# 0         1240.40
# 1         2955.47
# 2          951.16
# 3         4483.81
# 4         1655.98
#            ...
# 144402    3260.86
# 144403    1587.96
# 144404     951.19
# 144405     760.18
# 144406     938.13
# Name: 예측 절단시간, Length: 144407, dtype: float64

# %%
data22.to_csv('cut_predtion_rf.csv')

# %%
'''
from lightgbm.sklearn import LGBMRegressor
import lightgbm as lgb
# 0.4 기준으로 계속 그때그때 돌려보기

model = LGBMRegressor(n_estimators = 4000, boosting = 'dart', learning_rate = 0.07, max_depth = 10)
model.fit(x_train, y_train)

train_score= model.score(x_train, y_train)
print(train_score)

pred =model.predict(x_test)

test_score= explained_variance_score(pred, y_test)
print(test_score)
gap = train_score - test_score
print("학습률 예측률 차이 :", gap)
RMSE = mean_squared_error(y_test, pred)**0.5
print("rmse: ", RMSE)
'''
from sklearn.model_selection import GridSearchCV

params = {
    'num_iterations': [3000,4000,5000], 
    'learning_rate': [0.08,0.65,0.05], 
    'max_depth': [10,12,-1],  
    'booster' :['dart']
}


grid_search = GridSearchCV(LGBMRegressor(), params, cv=3, n_jobs=-1, scoring='neg_mean_squared_error')

grid_search.fit(x_train, y_train)

print(abs(grid_search.best_score_))
print(grid_search.best_params_) # 최적찾구, 마킹시간에 입력변수로 넣기
# Out:
# /usr/local/lib/python3.6/dist-packages/lightgbm/engine.py:118: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# 167935.3455809996
# {'booster': 'dart', 'learning_rate': 0.05, 'max_depth': 12, 'num_iterations': 3000}

# %%
model = LGBMRegressor(n_estimators = 3000, boosting = 'dart', learning_rate = 0.05, max_depth = 12) #학습률 낮추어 보기, 깊이 더 파보기
model.fit(x_train, y_train)

train_score= model.score(x_train, y_train)
print(train_score)

pred =model.predict(x_test)

test_score= explained_variance_score(pred, y_test)
print(test_score)
gap = train_score - test_score
print("학습률 예측률 차이 :", gap)
RMSE = mean_squared_error(y_test, pred)**0.5
print("rmse: ", RMSE)
# Out:
# 0.8899896477259127
# 0.8408187070232824
# 학습률 예측률 차이 : 0.049170940702630284
# rmse:  408.7683216404643

# %%
LGBM_model = LGBMRegressor(n_estimators = 2000, boosting = 'dart', learning_rate = 0.1, max_depth = 9, subsample: 0.8)
evals = [(x_test, y_test)]
LGBM_model.fit(x_train, y_train, early_stopping_rounds = 100, eval_metric = 'logloss', eval_set = evals, verbose = True)

train_score= model.score(x_train, y_train)
print(train_score)

pred =model.predict(x_test)

test_score= explained_variance_score(pred, y_test)
print(test_score)
gap = train_score - test_score
print("학습률 예측률 차이 :", gap)
RMSE = mean_squared_error(y_test, pred)**0.5
print("rmse: ", RMSE)
# Out:
#   File "<ipython-input-193-9ad7406cce7d>", line 1
#     LGBM_model = LGBMRegressor(n_estimators = 2000, boosting = 'dart', learning_rate = 0.1, max_depth = 9, subsample: 0.8)
#                                                                                                                     ^
# SyntaxError: invalid syntax

# %% [markdown]
# * 로그스케일 안한거 이거로 lgbm적용해보

# %%
pred2 = model.predict(x)
Data['예측 절단시간'] = pred2
Data
# Out:
#         Unnamed: 0  절단 길이 (m)  절단갯수  ...  절단장비_PS243  절단장비_PS963      예측 절단시간
# 0                0       21.9     1  ...           0           0   798.032120
# 1                1      111.8    46  ...           0           0  3133.897299
# 2                2       33.5     2  ...           0           0   874.913998
# 3                3      174.9    35  ...           0           0  4590.661324
# 4                4       66.6     7  ...           0           0  1762.074529
# ...            ...        ...   ...  ...         ...         ...          ...
# 144402      149263      124.0    33  ...           0           0  3409.618630
# 144403      149264      162.0    31  ...           0           0  4327.593610
# 144404      149265       28.9    56  ...           0           0   971.663173
# 144405      149266       25.6     1  ...           0           0   891.137215
# 144406      149268       20.7     8  ...           0           0   826.353936
#
# [144407 rows x 123 columns]

# %%
data3 = Data.iloc[:,-1]
data3
# Out:
# 0          798.032120
# 1         3133.897299
# 2          874.913998
# 3         4590.661324
# 4         1762.074529
#              ...
# 144402    3409.618630
# 144403    4327.593610
# 144404     971.663173
# 144405     891.137215
# 144406     826.353936
# Name: 예측 절단시간, Length: 144407, dtype: float64

# %%
data3.to_csv('cut_predition2.csv')

# %%
data = pd.read_csv("mark_dumdata.csv") # 데이터 수 제대로 안나온다면 , encoding = 'cp946' 했다가 돌리고 다시 지우고 돌리면 됨 ㅋㅋ..
data
# Out:
#         마킹 길이 (m)  절단 길이 (m)  마킹시간(초)  ...  절단장비_PS213  절단장비_PS243  절단장비_PS963
# 0            46.0       21.9      194  ...           0           0           0
# 1            33.9      111.8      324  ...           0           0           0
# 2            49.5       33.5      241  ...           0           0           0
# 3            75.7      174.9      483  ...           0           0           0
# 4            66.5       66.6      331  ...           0           0           0
# ...           ...        ...      ...  ...         ...         ...         ...
# 144402       75.2      124.0      464  ...           0           0           0
# 144403      139.8      162.0      827  ...           0           0           0
# 144404       18.5       28.9      165  ...           0           0           0
# 144405       63.7       25.6      345  ...           0           0           0
# 144406       11.4       20.7       63  ...           0           0           0
#
# ...

# %%
pred2 =model.predict(x_features)
pred_exp2 = np.expm1(pred2)
pred_exp2.shape
# Out:
# (144407,)

# %%
data['절단시간'] = pred_exp2
data
# Out:
#         마킹 길이 (m)  절단 길이 (m)  마킹시간(초)  ...  절단장비_PS243  절단장비_PS963         절단시간
# 0            46.0       21.9      194  ...           0           0   628.715963
# 1            33.9      111.8      324  ...           0           0  2921.210117
# 2            49.5       33.5      241  ...           0           0   836.442593
# 3            75.7      174.9      483  ...           0           0  4664.788456
# 4            66.5       66.6      331  ...           0           0  1665.455798
# ...           ...        ...      ...  ...         ...         ...          ...
# 144402       75.2      124.0      464  ...           0           0  3282.755002
# 144403      139.8      162.0      827  ...           0           0  4318.184501
# 144404       18.5       28.9      165  ...           0           0   879.049804
# 144405       63.7       25.6      345  ...           0           0   765.670286
# 144406       11.4       20.7       63  ...           0           0   678.605397
#
# ...

# %%
y_target = data['마킹시간(초)']
x_features = data.drop(['마킹시간(초)'],axis=1, inplace=False)
y_target_log = np.log1p(y_target)

x_train, x_test, y_train, y_test = train_test_split(x_features, y_target_log, test_size=0.3, random_state=0)

# %%
# 제곱그런거 안하고 바로 넣은경우
model = RandomForestRegressor()
model.fit(x_train, y_train)

train_score= model.score(x_train, y_train)
print("마킹시간 학습정도(train data) :", train_score)

pred =model.predict(x_test)
y_test_exp = np.expm1(y_test)
pred_exp = np.expm1(pred)

test_score= explained_variance_score(pred_exp, y_test_exp)
print("마킹시간 예측정도(test data) :", test_score)
gap = train_score - test_score
print("학습률 예측률 차이 :", gap)
# Out:
# 마킹시간 학습정도(train data) : 0.9601382550230123
# 마킹시간 예측정도(test data) : 0.6602949797099871
# 학습률 예측률 차이 : 0.29984327531302524

# %% [markdown]
# # case1. 마킹길이만 제곱

# %%
data.columns
# Out:
# Index(['마킹 길이 (m)', '절단 길이 (m)', '마킹시간(초)', '철판재질_32M60C  ', '철판재질_9NI     ',
#        '철판재질_A       ', '철판재질_AA      ', '철판재질_AAH32   ', '철판재질_AAH32-TM',
#        '철판재질_AAH36   ',
#        ...
#        '절단장비_PL911', '절단장비_PL921', '절단장비_PL922', '절단장비_PL961', '절단장비_PL973',
#        '절단장비_PL974', '절단장비_PS213', '절단장비_PS243', '절단장비_PS963', '절단시간'],
#       dtype='object', length=122)

# %%
mark_length = data['마킹 길이 (m)'] ** 2
mark_length
# Out:
# 0          2116.00
# 1          1149.21
# 2          2450.25
# 3          5730.49
# 4          4422.25
#             ...
# 144402     5655.04
# 144403    19544.04
# 144404      342.25
# 144405     4057.69
# 144406      129.96
# Name: 마킹 길이 (m), Length: 144407, dtype: float64

# %%
data['마킹길이제곱'] = mark_length
del data['마킹 길이 (m)']
data
# Out:
#         절단 길이 (m)  마킹시간(초)  철판재질_32M60C    ...  절단장비_PS963         절단시간    마킹길이제곱
# 0            21.9      194              0  ...           0   628.715963   2116.00
# 1           111.8      324              0  ...           0  2921.210117   1149.21
# 2            33.5      241              0  ...           0   836.442593   2450.25
# 3           174.9      483              0  ...           0  4664.788456   5730.49
# 4            66.6      331              0  ...           0  1665.455798   4422.25
# ...           ...      ...            ...  ...         ...          ...       ...
# 144402      124.0      464              0  ...           0  3282.755002   5655.04
# 144403      162.0      827              0  ...           0  4318.184501  19544.04
# 144404       28.9      165              0  ...           0   879.049804    342.25
# 144405       25.6      345              0  ...           0   765.670286   4057.69
# ...

# %%
y_target = data['마킹시간(초)']
x_features = data.drop(['마킹시간(초)'],axis=1, inplace=False)
y_target_log = np.log1p(y_target)

x_train, x_test, y_train, y_test = train_test_split(x_features, y_target_log, test_size=0.3, random_state=0)

# %%
# 제곱그런거 안하고 바로 넣은경우
model = RandomForestRegressor()
model.fit(x_train, y_train)

train_score= model.score(x_train, y_train)
print("마킹길이 제곱경우_마킹시간 학습정도(train data) :", train_score)

pred =model.predict(x_test)
y_test_exp = np.expm1(y_test)
pred_exp = np.expm1(pred)

test_score= explained_variance_score(pred_exp, y_test_exp)
print("마킹길이 제곱경우_마킹시간 예측정도(test data) :", test_score)
gap = train_score - test_score
print("마킹길이 제곱경우_학습률 예측률 차이 :", gap)
# Out:
# 마킹길이 제곱경우_마킹시간 학습정도(train data) : 0.9603178304866004
# 마킹길이 제곱경우_마킹시간 예측정도(test data) : 0.6590108003429103
# 마킹길이 제곱경우_학습률 예측률 차이 : 0.3013070301436901

# %% [markdown]
# # 절단길이도 제곱

# %%
data = pd.read_csv("mark_dumdata.csv") # 데이터 수 제대로 안나온다면 , encoding = 'cp946' 했다가 돌리고 다시 지우고 돌리면 됨 ㅋㅋ..
data
# Out:
#         마킹 길이 (m)  절단 길이 (m)  마킹시간(초)  ...  절단장비_PS213  절단장비_PS243  절단장비_PS963
# 0            46.0       21.9      194  ...           0           0           0
# 1            33.9      111.8      324  ...           0           0           0
# 2            49.5       33.5      241  ...           0           0           0
# 3            75.7      174.9      483  ...           0           0           0
# 4            66.5       66.6      331  ...           0           0           0
# ...           ...        ...      ...  ...         ...         ...         ...
# 144402       75.2      124.0      464  ...           0           0           0
# 144403      139.8      162.0      827  ...           0           0           0
# 144404       18.5       28.9      165  ...           0           0           0
# 144405       63.7       25.6      345  ...           0           0           0
# 144406       11.4       20.7       63  ...           0           0           0
#
# ...

# %%
cut_length = data['절단 길이 (m)'] ** 2
mark_length = data['마킹 길이 (m)'] ** 2
data['마킹길이제곱'] = mark_length
data['절단길이제곱'] = cut_length

# %%
del data['절단 길이 (m)']
del data['마킹 길이 (m)']
data
# Out:
#         마킹시간(초)  철판재질_32M60C    철판재질_9NI       ...  절단장비_PS963    마킹길이제곱    절단길이제곱
# 0           194              0              0  ...           0   2116.00    479.61
# 1           324              0              0  ...           0   1149.21  12499.24
# 2           241              0              0  ...           0   2450.25   1122.25
# 3           483              0              0  ...           0   5730.49  30590.01
# 4           331              0              0  ...           0   4422.25   4435.56
# ...         ...            ...            ...  ...         ...       ...       ...
# 144402      464              0              0  ...           0   5655.04  15376.00
# 144403      827              0              0  ...           0  19544.04  26244.00
# 144404      165              0              0  ...           0    342.25    835.21
# 144405      345              0              0  ...           0   4057.69    655.36
# ...

# %%
y_target = data['마킹시간(초)']
x_features = data.drop(['마킹시간(초)'],axis=1, inplace=False)
y_target_log = np.log1p(y_target)

x_train, x_test, y_train, y_test = train_test_split(x_features, y_target_log, test_size=0.3, random_state=0)

# %%
model = RandomForestRegressor()
model.fit(x_train, y_train)

train_score= model.score(x_train, y_train)
print("마킹길이, 절단길이 제곱경우_마킹시간 학습정도(train data) :", train_score)

pred =model.predict(x_test)
y_test_exp = np.expm1(y_test)
pred_exp = np.expm1(pred)

test_score= explained_variance_score(pred_exp, y_test_exp)
print("마킹길이, 절단길이 제곱경우_마킹시간 예측정도(test data) :", test_score)
gap = train_score - test_score
print("마킹길이, 절단길이 제곱경우_학습률 예측률 차이 :", gap)
# Out:
# 마킹길이, 절단길이 제곱경우_마킹시간 학습정도(train data) : 0.9580936875791015
# 마킹길이, 절단길이 제곱경우_마킹시간 예측정도(test data) : 0.6604439821155745
# 마킹길이, 절단길이 제곱경우_학습률 예측률 차이 : 0.297649705463527

# %% [markdown]
# # 마킹시간, 절단시간 세제곱

# %%
data = pd.read_csv("mark_dumdata.csv") # 데이터 수 제대로 안나온다면 , encoding = 'cp946' 했다가 돌리고 다시 지우고 돌리면 됨 ㅋㅋ..
data
# Out:
#         마킹 길이 (m)  절단 길이 (m)  마킹시간(초)  ...  절단장비_PS213  절단장비_PS243  절단장비_PS963
# 0            46.0       21.9      194  ...           0           0           0
# 1            33.9      111.8      324  ...           0           0           0
# 2            49.5       33.5      241  ...           0           0           0
# 3            75.7      174.9      483  ...           0           0           0
# 4            66.5       66.6      331  ...           0           0           0
# ...           ...        ...      ...  ...         ...         ...         ...
# 144402       75.2      124.0      464  ...           0           0           0
# 144403      139.8      162.0      827  ...           0           0           0
# 144404       18.5       28.9      165  ...           0           0           0
# 144405       63.7       25.6      345  ...           0           0           0
# 144406       11.4       20.7       63  ...           0           0           0
#
# ...

# %%
cut_length3 = data['절단 길이 (m)'] ** 3
mark_length3 = data['마킹 길이 (m)'] ** 3
data['마킹길이제곱'] = mark_length3
data['절단길이제곱'] = cut_length3

# %%
del data['절단 길이 (m)']
del data['마킹 길이 (m)']
data
# Out:
#         마킹시간(초)  철판재질_32M60C    ...       마킹길이제곱       절단길이제곱
# 0           194              0  ...    97336.000    10503.459
# 1           324              0  ...    38958.219  1397415.032
# 2           241              0  ...   121287.375    37595.375
# 3           483              0  ...   433798.093  5350192.749
# 4           331              0  ...   294079.625   295408.296
# ...         ...            ...  ...          ...          ...
# 144402      464              0  ...   425259.008  1906624.000
# 144403      827              0  ...  2732256.792  4251528.000
# 144404      165              0  ...     6331.625    24137.569
# 144405      345              0  ...   258474.853    16777.216
# 144406       63              0  ...     1481.544     8869.743
#
# [144407 rows x 121 columns]

# %%
y_target = data['마킹시간(초)']
x_features = data.drop(['마킹시간(초)'],axis=1, inplace=False)
y_target_log = np.log1p(y_target)

x_train, x_test, y_train, y_test = train_test_split(x_features, y_target_log, test_size=0.3, random_state=0)

# %%
model = RandomForestRegressor()
model.fit(x_train, y_train)

train_score= model.score(x_train, y_train)
print("마킹길이, 절단길이 세제곱경우_마킹시간 학습정도(train data) :", train_score)

pred =model.predict(x_test)
y_test_exp = np.expm1(y_test)
pred_exp = np.expm1(pred)

test_score= explained_variance_score(pred_exp, y_test_exp)
print("마킹길이, 절단길이 세제곱경우_마킹시간 예측정도(test data) :", test_score)
gap = train_score - test_score
print("마킹길이, 절단길이 세제곱경우_학습률 예측률 차이 :", gap)
# Out:
# 마킹길이, 절단길이 세제곱경우_마킹시간 학습정도(train data) : 0.9579022802786752
# 마킹길이, 절단길이 세제곱경우_마킹시간 예측정도(test data) : 0.6591344822720209
# 마킹길이, 절단길이 세제곱경우_학습률 예측률 차이 : 0.2987677980066543

# %%
y = data['마킹시간(초)']
x = data.drop(['마킹시간(초)'],axis=1, inplace=False)

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=0)

# %%
# 로그스케일 안하고
model = RandomForestRegressor()
model.fit(x_train, y_train)

train_score= model.score(x_train, y_train)
print("마킹길이, 절단길이 세제곱경우_마킹시간 학습정도(train data) :", train_score)

pred =model.predict(x_test)

test_score= explained_variance_score(pred, y_test)
print("마킹길이, 절단길이 세제곱경우_마킹시간 예측정도(test data) :", test_score)
gap = train_score - test_score
print("마킹길이, 절단길이 세제곱경우_학습률 예측률 차이 :", gap)
# Out:
# 마킹길이, 절단길이 세제곱경우_마킹시간 학습정도(train data) : 0.9557924423339736
# 마킹길이, 절단길이 세제곱경우_마킹시간 예측정도(test data) : 0.6737813470146128
# 마킹길이, 절단길이 세제곱경우_학습률 예측률 차이 : 0.28201109531936086

# %%
from sklearn.metrics import mean_squared_error

RMSE = mean_squared_error(y_test, pred)**0.5
RMSE
# Out:
# 101.47580704354155

# %%
pred3 = model.predict(x)
data['예측 마킹시간'] = pred3
data
# Out:
#         마킹시간(초)  철판재질_32M60C    ...     예측 절단시간     예측 마킹시간
# 0           194              0  ...  297.243333  297.243333
# 1           324              0  ...  315.110833  315.110833
# 2           241              0  ...  253.484238  253.484238
# 3           483              0  ...  621.327000  621.327000
# 4           331              0  ...  307.479833  307.479833
# ...         ...            ...  ...         ...         ...
# 144402      464              0  ...  464.948000  464.948000
# 144403      827              0  ...  761.245752  761.245752
# 144404      165              0  ...  199.110000  199.110000
# 144405      345              0  ...  347.317500  347.317500
# 144406       63              0  ...   89.481667   89.481667
#
# [144407 rows x 123 columns]

# %%
data4 = data.iloc[:,-1]
data4
# Out:
# 0         297.243333
# 1         315.110833
# 2         253.484238
# 3         621.327000
# 4         307.479833
#              ...
# 144402    464.948000
# 144403    761.245752
# 144404    199.110000
# 144405    347.317500
# 144406     89.481667
# Name: 예측 마킹시간, Length: 144407, dtype: float64

# %%
data4.to_csv('mark_predition.csv')

# %%
data
# Out:
#         마킹시간(초)  철판재질_32M60C    ...     예측 절단시간     예측 마킹시간
# 0           194              0  ...  297.243333  297.243333
# 1           324              0  ...  315.110833  315.110833
# 2           241              0  ...  253.484238  253.484238
# 3           483              0  ...  621.327000  621.327000
# 4           331              0  ...  307.479833  307.479833
# ...         ...            ...  ...         ...         ...
# 144402      464              0  ...  464.948000  464.948000
# 144403      827              0  ...  761.245752  761.245752
# 144404      165              0  ...  199.110000  199.110000
# 144405      345              0  ...  347.317500  347.317500
# 144406       63              0  ...   89.481667   89.481667
#
# [144407 rows x 123 columns]

# %%
del data['예측 절단시간']
del data['예측 마킹시간']
data
# Out:
#         마킹시간(초)  철판재질_32M60C    ...       마킹길이제곱       절단길이제곱
# 0           194              0  ...    97336.000    10503.459
# 1           324              0  ...    38958.219  1397415.032
# 2           241              0  ...   121287.375    37595.375
# 3           483              0  ...   433798.093  5350192.749
# 4           331              0  ...   294079.625   295408.296
# ...         ...            ...  ...          ...          ...
# 144402      464              0  ...   425259.008  1906624.000
# 144403      827              0  ...  2732256.792  4251528.000
# 144404      165              0  ...     6331.625    24137.569
# 144405      345              0  ...   258474.853    16777.216
# 144406       63              0  ...     1481.544     8869.743
#
# [144407 rows x 121 columns]

# %%
data['예측 절단시간'] = pred2
data
# Out:
#         마킹시간(초)  철판재질_32M60C    ...       절단길이제곱      예측 절단시간
# 0           194              0  ...    10503.459   798.032120
# 1           324              0  ...  1397415.032  3133.897299
# 2           241              0  ...    37595.375   874.913998
# 3           483              0  ...  5350192.749  4590.661324
# 4           331              0  ...   295408.296  1762.074529
# ...         ...            ...  ...          ...          ...
# 144402      464              0  ...  1906624.000  3409.618630
# 144403      827              0  ...  4251528.000  4327.593610
# 144404      165              0  ...    24137.569   971.663173
# 144405      345              0  ...    16777.216   891.137215
# 144406       63              0  ...     8869.743   826.353936
#
# [144407 rows x 122 columns]

# %%
y = data['마킹시간(초)']
x = data.drop(['마킹시간(초)'],axis=1, inplace=False)

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=0)

# %%
''' 랜덤포레스트
마킹길이, 절단길이 세제곱경우_마킹시간 학습정도(train data) : 0.9557924423339736
마킹길이, 절단길이 세제곱경우_마킹시간 예측정도(test data) : 0.6737813470146128
마킹길이, 절단길이 세제곱경우_학습률 예측률 차이 : 0.28201109531936086
'''

from lightgbm.sklearn import LGBMRegressor
import lightgbm as lgb

model = LGBMRegressor(n_estimators = 1000, boosting = 'dart', learning_rate = 0.05)
model.fit(x_train, y_train)

train_score= model.score(x_train, y_train)
print(train_score)

pred =model.predict(x_test)

test_score= explained_variance_score(pred, y_test)
print(test_score)
gap = train_score - test_score
print("학습률 예측률 차이 :", gap)
RMSE = mean_squared_error(y_test, pred)**0.5
print("rmse: ", RMSE)
# Out:
# 0.7604652607281086
# 0.6380964984930503
# 학습률 예측률 차이 : 0.12236876223505833
# rmse:  99.98385976307978

# %%
from lightgbm.sklearn import LGBMRegressor
import lightgbm as lgb

model = LGBMRegressor(n_estimators = 4000, boosting = 'dart', learning_rate = 0.005,max_depth=-1)
model.fit(x_train, y_train)

train_score= model.score(x_train, y_train)
print(train_score)

pred =model.predict(x_test)

test_score= explained_variance_score(pred, y_test)
print(test_score)
gap = train_score - test_score
print("학습률 예측률 차이 :", gap)
RMSE = mean_squared_error(y_test, pred)**0.5
print("rmse: ", RMSE)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-171-a7e83a87e8ff> in <module>()
#       3
#       4 model = LGBMRegressor(n_estimators = 4000, boosting = 'dart', learning_rate = 0.005,max_depth=-1)
# ----> 5 model.fit(x_train, y_train)
#       6
#       7 train_score= model.score(x_train, y_train)
#
# /usr/local/lib/python3.6/dist-packages/lightgbm/sklearn.py in fit(self, X, y, sample_weight, init_score, eval_set, eval_names, eval_sample_weight, eval_init_score, eval_metric, early_stopping_rounds, verbose, feature_name, categorical_feature, callbacks)
#     683                                        verbose=verbose, feature_name=feature_name,
#     684                                        categorical_feature=categorical_feature,
# --> 685                                        callbacks=callbacks)
#     686         return self
#     687
#
# ...

# %%
del data['예측 절단시간']
data
# Out:
#         마킹시간(초)  철판재질_32M60C    ...       마킹길이제곱       절단길이제곱
# 0           194              0  ...    97336.000    10503.459
# 1           324              0  ...    38958.219  1397415.032
# 2           241              0  ...   121287.375    37595.375
# 3           483              0  ...   433798.093  5350192.749
# 4           331              0  ...   294079.625   295408.296
# ...         ...            ...  ...          ...          ...
# 144402      464              0  ...   425259.008  1906624.000
# 144403      827              0  ...  2732256.792  4251528.000
# 144404      165              0  ...     6331.625    24137.569
# 144405      345              0  ...   258474.853    16777.216
# 144406       63              0  ...     1481.544     8869.743
#
# [144407 rows x 121 columns]

# %%
pred22 = model.predict(x)
data['예측 절단시간'] = pred22
data
# Out:
#         마킹시간(초)  철판재질_32M60C    ...       절단길이제곱  예측 절단시간
# 0           194              0  ...    10503.459  1240.40
# 1           324              0  ...  1397415.032  2955.47
# 2           241              0  ...    37595.375   951.16
# 3           483              0  ...  5350192.749  4483.81
# 4           331              0  ...   295408.296  1655.98
# ...         ...            ...  ...          ...      ...
# 144402      464              0  ...  1906624.000  3260.86
# 144403      827              0  ...  4251528.000  1587.96
# 144404      165              0  ...    24137.569   951.19
# 144405      345              0  ...    16777.216   760.18
# 144406       63              0  ...     8869.743   938.13
#
# [144407 rows x 122 columns]

# %%
data.to_csv('마킹시간_절단시간입력_세제곱.csv')
